# %% [markdown]
# <a href="https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt_oss_(20B)_Reinforcement_Learning_2048_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Free Colab"/></a>

# %% [markdown]
# # Goal: Make GPT-OSS play games with Reinforcement Learning
#
# Our goal is to make GPT-OSS play the 2048 game with reinforcement learning, or a variant of it called [GRPO](https://arxiv.org/abs/2501.12948).
#
# We want the model to devise a strategy to play 2048, and we will run this strategy until we win or lose. We then reward the model if it created a good strategy (winning the game), and we'll penalize it (negative reward) if the strategy was a bad one.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f9/2048_win.png/500px-2048_win.png" height=300 />

# %% [markdown]
# # Installation
# We'll be using [Unsloth](https://github.com/unslothai/unsloth) to do RL on GPT-OSS 20B. Unsloth saves 70% VRAM usage and makes reinforcement learning 2 to 6x faster, which allows us to fit GPT-OSS RL in a free Google Colab instance.

# %%
# %%capture
import os, importlib.util
# !pip install --upgrade -qqq uv
if importlib.util.find_spec("torch") is None or "COLAB_" in "".join(os.environ.keys()):    
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    # !uv pip install -qqq \
        "torch>=2.8.0" "triton>=3.4.0" {get_numpy} torchvision bitsandbytes "transformers==4.56.2" \
        "unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo" \
        "unsloth[base] @ git+https://github.com/unslothai/unsloth" \
        git+https://github.com/triton-lang/triton.git@0add68262ab0a2e33b84524346cb27cbb2787356#subdirectory=python/triton_kernels
elif importlib.util.find_spec("unsloth") is None:
    # !uv pip install -qqq unsloth
# !uv pip install --upgrade --no-deps transformers==4.56.2 tokenizers trl==0.22.2 unsloth unsloth_zoo

# %% [markdown]
# We'll load GPT-OSS 20B and set some parameters:
# * `max_seq_length = 768` The maximum context length of the model. Increasing it will use more memory, and 768 was the maximum we found to fit on a free 15GB Tesla T4 machine
# * `lora_rank = 4` The larger this number, the smarter the RL process, but the slower and more memory usage
# * `load_in_4bit = True` Uses quantization to reduce memory usage by 75% without reducing accuracy that much. `load_in_16bit` will be faster but will need a 80GB GPU (H100, B200)
# * `offload_embedding = True` New Unsloth optimization which moves the embedding to CPU RAM, reducing VRAM by 1GB.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 768 # Can increase for longer RL output
lora_rank = 4        # Larger rank = smarter, but slower
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gpt-oss-20b", # unsloth/gpt-oss-20b-BF16 for H100s
    max_seq_length = max_seq_length,
    load_in_4bit = True,      # False for LoRA 16bit. Choose False on H100s
    offload_embedding = True, # Reduces VRAM by 1GB
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.10.1: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gpt_oss won't work! Using float32.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.37G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/165 [00:00<?, ?B/s]
# Unsloth: Offloading embeddings to RAM to save 1.08 GB.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/27.9M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# To do efficient RL, we will use [LoRA](https://arxiv.org/abs/2106.09685), which allows us to only add 1 to 5% of extra weights to the model for finetuning purposes. This allows us to save memory usage by over 60%, and yet it retains good accuracy. Read Unsloth's [GPT-OSS RL Guide](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) for more details.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank*2, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# # 2048 game
#
# We used GPT-5 to create a variant of the 2048 game. It should output the current game board state, and allow us to advance the game board state with 1 action (up, down, left, right).

# %%
#@title (Collapsible) 2048 Game Implementation
from dataclasses import dataclass, field
from typing import List, Tuple, Optional
import random
import copy

def _compress_and_merge_row_left(row: List[int]) -> Tuple[List[int], int, bool]:
    n = len(row)
    tiles = [x for x in row if x != 0]
    gained = 0
    i = 0
    merged = []
    while i < len(tiles):
        if i + 1 < len(tiles) and tiles[i] == tiles[i + 1]:
            v = tiles[i] * 2
            gained += v
            merged.append(v)
            i += 2
        else:
            merged.append(tiles[i])
            i += 1
    merged += [0] * (n - len(merged))
    changed = merged != row
    return merged, gained, changed

def _move_left(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    changed_any = False
    total_gain = 0
    new_board = []
    for row in board:
        new_row, gained, changed = _compress_and_merge_row_left(row)
        new_board.append(new_row)
        total_gain += gained
        changed_any = changed_any or changed
    return new_board, total_gain, changed_any

def _move_right(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    changed_any = False
    total_gain = 0
    new_board = []
    for row in board:
        rev = list(reversed(row))
        new_rev, gained, changed = _compress_and_merge_row_left(rev)
        new_row = list(reversed(new_rev))
        new_board.append(new_row)
        total_gain += gained
        changed_any = changed_any or changed
    return new_board, total_gain, changed_any

def _transpose(board: List[List[int]]) -> List[List[int]]:
    return [list(row) for row in zip(*board)]

def _move_up(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    t = _transpose(board)
    moved, gain, changed = _move_left(t)
    return _transpose(moved), gain, changed

def _move_down(board: List[List[int]]) -> Tuple[List[List[int]], int, bool]:
    t = _transpose(board)
    moved, gain, changed = _move_right(t)
    return _transpose(moved), gain, changed

def _empty_cells(board: List[List[int]]) -> List[Tuple[int, int]]:
    size = len(board)
    return [(r, c) for r in range(size) for c in range(size) if board[r][c] == 0]

def _can_move(board: List[List[int]]) -> bool:
    if _empty_cells(board):
        return True
    size = len(board)
    for r in range(size):
        for c in range(size - 1):
            if board[r][c] == board[r][c + 1]:
                return True
    for r in range(size - 1):
        for c in range(size):
            if board[r][c] == board[r + 1][c]:
                return True
    return False

@dataclass
class GameBoard:
    size: int
    seed: Optional[int] = None
    target: int = 2048
    probability_fours: float = 0.10 # originally spawns (4) 10% of the time!
    _rng: random.Random = field(init=False, repr=False)
    _board: List[List[int]] = field(init=False, repr=False)
    _score: int = field(default=0, init=False, repr=False)
    _state: str = field(default="ongoing", init=False, repr=False)

    def __post_init__(self):
        if self.size < 2:
            raise ValueError("Board size must be at least 2.")
        self._rng = random.Random(self.seed)
        self._board = [[0 for _ in range(self.size)] for _ in range(self.size)]
        self._add_random_tile()
        self._add_random_tile()
        self._update_state_after_change()

    class _BoardView:
        def __init__(self, game: "GameBoard"):
            self._game = game
        def __iter__(self):
            return iter(self._game._board)
        def __len__(self):
            return len(self._game._board)
        def __getitem__(self, idx):
            return self._game._board[idx]
        def __repr__(self) -> str:
            return repr(self._game._board)
        __str__ = __repr__
        def do_action(self, key: str) -> None:
            self._game.do_action(key)
        def state(self) -> str:
            return self._game.state()
        def pretty(self, colors: bool = True, border: bool = True, dot_for_zero: bool = True) -> str:
            return self._game._render_pretty(colors=colors, border=border, dot_for_zero=dot_for_zero)

    def board(self) -> "_BoardView":
        return GameBoard._BoardView(self)
    def state(self) -> str:
        return self._state
    def score(self) -> int:
        return self._score
    def do_action(self, key: str) -> None:
        if self._state != "ongoing":
            return
        if not isinstance(key, str) or len(key) == 0:
            self._state = "failed"
            return
        k = key.strip().lower()
        if k == "q":
            self._state = "failed"
            return
        move_map = {"a": _move_left, "d": _move_right, "w": _move_up, "s": _move_down}
        if k not in move_map:
            self._state = "failed"
            return
        mover = move_map[k]
        new_board, gain, changed = mover(self._board)
        if changed:
            self._board = new_board
            self._score += gain
            self._add_random_tile()
        self._update_state_after_change()
    def _add_random_tile(self) -> bool:
        empties = _empty_cells(self._board)
        if not empties:
            return False
        r, c = self._rng.choice(empties)
        self._board[r][c] = 4 if self._rng.random() < self.probability_fours else 2
        return True
    def _update_state_after_change(self) -> None:
        if any(self.target in row for row in self._board):
            self._state = "success"
            return
        if not _can_move(self._board):
            self._state = "failed"
            return
        self._state = "ongoing"
    def _render_pretty(self, colors: bool = True, border: bool = True, dot_for_zero: bool = True) -> str:
        """
        Pretty-print the board with colors that scale from 0 up to self.target.
        Uses ANSI 256-color codes (works in most terminals). Set colors=False to disable.
        """
        import math

        b = self._board
        mx = max((max(row) for row in b), default=0)
        cell_w = max(3, len(str(mx)))

        RESET = "\x1b[0m"

        # A smooth-ish gradient from cool → warm
        # (blue/cyan/green → yellow/orange/red). Tweak or expand as you like.
        GRAD = [33, 39, 45, 51, 50, 49, 48, 47, 46, 82, 118, 154, 190, 226, 220, 214, 208, 202, 196]
        ZERO_FG = 239  # dim gray

        def color_code(v: int) -> str:
            if not colors:
                return ""
            if v == 0:
                return f"\x1b[38;5;{ZERO_FG}m"
            # Normalize by exponent relative to target: r in [0,1]
            t = max(2, self.target)  # safety; avoid log2(1)
            # Guard: if v is not a power of two or is <1, handle gracefully
            try:
                r = max(0.0, min(1.0, math.log2(v) / math.log2(t)))
            except ValueError:
                r = 0.0
            idx = int(round(r * (len(GRAD) - 1)))
            return f"\x1b[38;5;{GRAD[idx]}m"

        def fmt(v: int) -> str:
            s = "." if (v == 0 and dot_for_zero) else str(v)
            s = s.rjust(cell_w)
            return color_code(v) + s + (RESET if colors else "")

        def hline(left: str, mid: str, right: str) -> str:
            return left + mid.join("─" * cell_w for _ in range(self.size)) + right

        rows = []
        if border:
            rows.append(hline("┌", "┬", "┐"))
        for r in range(self.size):
            content = "│".join(fmt(v) for v in b[r])
            rows.append(("│" + content + "│") if border else content)
            if border:
                rows.append(hline("└" if r == self.size - 1 else "├",
                                "┴" if r == self.size - 1 else "┼",
                                "┘" if r == self.size - 1 else "┤"))
        return "\n".join(rows)

# %% [markdown]
# For example let's create a board of size 5 X 5 and set the target to 8 instead of 2048.
#
# **[NOTE]** 2048 originally spawns a (4) 10% of the time! We can disable this for harder games. See [Wikipedia page](https://en.wikipedia.org/wiki/2048_(video_game)) for more details.

# %%
game = GameBoard(size = 5, seed = 42, target = 8, probability_fours = 0.10)
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  2│  .│  .│  .│  2│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game
# Out:
# GameBoard(size=5, seed=42, target=8, probability_fours=0.1)

# %% [markdown]
# We'll use WASD for the action space:
#
# ```
#    W
# A  S  D
# ```
# Also `game.state()` will say `success` if we succeeded in getting the target!

# %%
game.do_action("A")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  2│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  4│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("W")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  4│  .│  2│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  2│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("D")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  .│  4│  2│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  2│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  4│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("W")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  4│  .│  .│  4│  4│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  4│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ ongoing

# %%
game.do_action("D")
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┬───┬───┐
# │  .│  .│  2│  4│  8│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  4│
# ├───┼───┼───┼───┼───┤
# │  .│  .│  .│  .│  .│
# └───┴───┴───┴───┴───┘ success

# %% [markdown]
# If we do some other action that's not part of the action space, we will get an error, and the game will not accept anymore actions.

# %%
game = GameBoard(size = 3, seed = 42, target = 8, probability_fours = 0.10)
game.do_action("AA") # Not in WASD
game.do_action("W")  # Doesn't do anything
game.do_action("A")  # Doesn't do anything
print(game.board().pretty(), game.state())
# Out:
# ┌───┬───┬───┐
# │  .│  4│  .│
# ├───┼───┼───┤
# │  .│  .│  2│
# ├───┼───┼───┤
# │  .│  .│  .│
# └───┴───┴───┘ failed

# %% [markdown]
# # RL Environment Setup
#
# We'll set up a function to accept some strategy that'll emit an action within `WASD` and check the game state.
#
# We'll also add a timer to only execute the stratgegy for 2 seconds maximum, otherwise it might never terminate!

# %%
from typing import Callable
from unsloth import execute_with_time_limit

def _execute_strategy(strategy : Callable, game : GameBoard):
    assert callable(strategy)

    steps = 0
    while game.state() == "ongoing":
        action = strategy(list(game.board()))
        steps += 1
        if type(action) is not str:
            return steps, "failed"
        game.do_action(action)
    return steps, game.state()

@execute_with_time_limit(2)
def execute_strategy(strategy : Callable, game : GameBoard):
    return _execute_strategy(strategy, game)

# %% [markdown]
# Let's make a generic strategy to just hit `W`. We should expect this generic strategy to fail:

# %%
def always_move_left(board):
    return "W"

game = GameBoard(size = 8, seed = 42, target = 2048, probability_fours = 0.10)
try:
    execute_strategy(always_move_left, game)
except TimeoutError as e:
    print(f"Timed out with error = {str(e)}")
# Out:
# Timed out with error = Timed out after 2s

# %% [markdown]
# To allow longer strategies for GPT-OSS Reinforcement Learning, we shall allow a 5 second timer.

# %%
@execute_with_time_limit(5)
def execute_strategy(strategy : Callable, game : GameBoard):
    return _execute_strategy(strategy, game)

# %% [markdown]
# # Code Execution
#
# To execute and create a new Python function, we first have to check if the function does not call other global variables or cheat. This is called `countering reward hacking` since we don't want the function to cheat.
#
# For example the below piece of code is fine, since it only imports Python level functions. We use `check_python_modules`:

# %%
from unsloth import check_python_modules

sample = """
def strategy(board):
    import math
    from typing import Callable
    return "W"
"""
ok, info = check_python_modules(sample)
print("Only Python imports?", ok)
print(info)
# Out:
# Only Python imports? True
# {'stdlib': ['math', 'typing'], 'non_stdlib': [], 'relative_imports': 0}

# %% [markdown]
# For the below piece of code, since we import `numpy`, we should not allow the execution:

# %%
sample = """
def strategy(board):
    from numpy import matmul
    return "W"
"""
ok, info = check_python_modules(sample)
print("Only Python imports?", ok)
print(info)
# Out:
# Only Python imports? False
# {'stdlib': [], 'non_stdlib': ['numpy'], 'relative_imports': 0}

# %% [markdown]
# We also disallow global variable access. We'll use Unsloth's `create_locked_down_function` function

# %%
from unsloth import create_locked_down_function
function = """
def import_numpy():
    np.matmul
    print("Success")
"""
f = create_locked_down_function(function)
try:
    f()
except Exception as e:
    print(str(e))
# Out:
# name 'np' is not defined

# %%
from unsloth import create_locked_down_function
function = """
def add(a, b):
    def adder(a):
        return a + b
    return adder(b) + b
"""
f = create_locked_down_function(function)
try:
    print(f(10, 20))
except Exception as e:
    print(str(e))
# Out:
# 60

# %% [markdown]
# # Data & RL task setup
#
# We now have to create a prompt to tell the model to create a strategy for the 2048 game. You can customize this to some other task for another RL task.

# %%
prompt = """
Create a new short 2048 strategy using only native Python code.
You are given a list of list of numbers for the current board state.
Output one action for "W", "A", "S", "D" on what is the optimal next step.
Output your new short function in backticks using the format below:
```python
def strategy(board):
    return "W" # Example
```
All helper functions should be inside def strategy. Only output the short function `strategy`.
""".strip()
print(prompt)
# Out:
# Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function `strategy`.

# %% [markdown]
# First, let's prompt GPT-OSS without RL and see how it goes:

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 512,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-10-05
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function `strategy`.<|end|><|start|>assistant<|channel|>analysis<|message|>We need simple heuristic: return random move or based on empty spaces. Provide function.<|end|><|start|>assistant<|channel|>final<|message|>```python
# def strategy(board):
#     # Count empty cells and choose move that reduces board density
#     empty_counts = {
#         "W": sum(row.count(0) for row in board[1:]),
#         "S": sum(row.count(0) for row in board[:-1]),
#         "A": sum(col.count(0) for col in zip(*board)[1:]),
#         "D": sum(col.count(0) for col in zip(*board)[:-1]),
#     }
#     # Prefer the direction with the most empty cells
#     return max(empty_counts, key=empty_counts.get)
# ```<|return|>

# %% [markdown]
# # Reward functions
#
# We now design a `extract_function` function which simply extracts the function wrapped in 3 back ticks.
#
# And 3 reward functions:
#
# 1. `function_works` which rewards the model if the strategy is a valid Python function.
# 2. `no_cheating` which checks if the function imported other modules, and if it did, we penalize it.
# 3. `strategy_succeeds` which checks if the game strategy actually succeeds in attaining 2048 after running the auto-generated strategy.

# %%
def extract_function(text):
    if text.count("```") >= 2:
        first = text.find("```") + 3
        second = text.find("```", first)
        fx = text[first : second].strip()
        fx = fx.removeprefix("python\n")
        fx = fx[fx.find("def"):]
        if fx.startswith("def strategy(board):"): return fx
    return None
print(extract_function(prompt))
# Out:
# def strategy(board):
#     return "W" # Example

# %% [markdown]
# Below is our `function_works` reward function which uses Python's `exec` but guarded by not allowing leakage of local and global variables. We can also use `check_python_modules` first to check if there are errors before even executing the function:

# %%
ok, info = check_python_modules("def a")
ok, info
# Out:
# (False,
#  {'error': "SyntaxError: expected '(' (<unknown>, line 1)",
#   'stdlib': [],
#   'non_stdlib': [],
#   'relative_imports': 0})

# %%
def function_works(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_python_modules(function)
        if function is None or "error" in info:
            score = -2.0
        else:
            try:
                new_strategy = create_locked_down_function(function)
                score = 1.0
            except:
                score = -0.5
        scores.append(score)
    return scores

# %% [markdown]
# `no_cheating` checks if the function cheated since it might have imported Numpy or other functions:

# %%
def no_cheating(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_python_modules(function)
            scores.append(1.0 if ok else -20.0) # Penalize heavily!
        else:
            scores.append(-1.0) # Failed creating function
    return scores

# %% [markdown]
# Next `strategy_succeeds` checks if the strategy actually allows the game to terminate. Imagine if the strategy simply returned "W" which would fail after a time limit of 10 seconds.
#
# We also add a global `PRINTER` to print out the strategy and board state.

# %%
import numpy as np
global PRINTER
PRINTER = 0
def strategy_succeeds(completions, **kwargs):
    global PRINTER
    scores = []
    # Generate a random game board with seed
    seed = np.random.randint(10000)
    for completion in completions:
        printed = False
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if PRINTER % 5 == 0:
            printed = True
            print(function)
        PRINTER += 1
        if function is not None:
            ok, info = check_python_modules(function)
        if function is None or "error" in info:
            scores.append(0)
            continue
        try:
            new_strategy = create_locked_down_function(function)
        except:
            scores.append(0)
            continue
        try:
            game = GameBoard(size = 6, seed = seed, target = 2048, probability_fours = 0.10)
            steps, game_state = execute_strategy(new_strategy, game)
            print(f"Steps = {steps} State = {game_state}")
            if printed is False:
                print(function)
            print(game.board().pretty())
            if game_state == "success":
                scores.append(20.0) # Success - massively reward!
            else:
                scores.append(2.0) # Failed but function works!
        except TimeoutError as e:
            print("Timeout")
            scores.append(-1.0) # Failed with timeout
        except Exception as e:
            print(f"Exception = {str(e)}")
            scores.append(-3.0) # Failed
    return scores

# %% [markdown]
# We'll now create the dataset which includes a replica of our prompt. Remember to add a reasoning effort of low! You can choose high reasoning mode, but this'll only work on more memory GPUs like H100s.

# %%
from datasets import Dataset
dataset = Dataset.from_list([{"prompt" : [{"role": "user", "content": prompt.strip()}], "answer" : 0, "reasoning_effort": "low"}]*1000)
maximum_length = len(tokenizer.apply_chat_template([{"role": "user", "content": prompt.strip()}], add_generation_prompt = True))
print(maximum_length)
dataset[0]
# Out:
# 181
# {'prompt': [{'content': 'Create a new short 2048 strategy using only native Python code.\nYou are given a list of list of numbers for the current board state.\nOutput one action for "W", "A", "S", "D" on what is the optimal next step.\nOutput your new short function in backticks using the format below:\n```python\ndef strategy(board):\n    return "W" # Example\n```\nAll helper functions should be inside def strategy. Only output the short function `strategy`.',
#    'role': 'user'}],
#  'answer': 0,
#  'reasoning_effort': 'low'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations! We also support GSPO, GAPO, Dr GRPO and more! Go the Unsloth [Reinforcement Learning Docs](https://docs.unsloth.ai/get-started/reinforcement-learning-rl-guide) for more options.

# %%
max_prompt_length = maximum_length + 1 # + 1 just in case!
max_completion_length = max_seq_length - max_prompt_length

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    temperature = 1.0,
    learning_rate = 5e-5,
    weight_decay = 0.001,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 2, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 1000,
    save_steps = 100,
    report_to = "none", # Can use Weights & Biases, TrackIO
    output_dir = "outputs",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 1,
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 2

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        function_works,
        no_cheating,
        strategy_succeeds,
    ],
    args = training_args,
    train_dataset = dataset,

    # For optional training + evaluation
    # train_dataset = new_dataset["train"],
    # eval_dataset = new_dataset["test"],
)
# Out:
# Unsloth: Switching to float32 training since model cannot work with float16

# %% [markdown]
# And let's train the model!
#
# **NOTE** A T4 free GPU might take 5 minutes for one generation sadly since it's an old GPU - A100 or H100 will be much faster!

# %%
trainer.train()
# Out:
# Steps = 1722 State = failed
# Steps = 1 State = failed
# Steps = 1097 State = success
# Steps = 1663 State = failed
# Steps = 1591 State = failed
# Steps = 1 State = failed
# Steps = 1972 State = success
# Steps = 1089 State = success
# Steps = 1 State = failed
# Steps = 1174 State = success
# Steps = 1229 State = success
# Steps = 1325 State = failed
# Steps = 1256 State = success
# Steps = 1406 State = failed
# Steps = 1062 State = failed
# Steps = 1213 State = success
# Steps = 1167 State = success
# Steps = 1 State = failed
# Steps = 1291 State = success
# Steps = 1417 State = success
# Steps = 1154 State = success
# Steps = 1 State = failed
# Steps = 2013 State = failed
# Steps = 1278 State = success
# Steps = 2251 State = failed
# Steps = 1303 State = success
# Steps = 1 State = failed
# Steps = 1805 State = success
# Steps = 329 State = failed
# Steps = 997 State = failed
# Steps = 1208 State = success
# Steps = 9 State = failed
# Steps = 1238 State = success
# Steps = 1420 State = failed
# Steps = 1721 State = success
# Steps = 1362 State = success
# Steps = 1198 State = success
# Steps = 1216 State = success
# Steps = 1296 State = success
# Steps = 1166 State = success
# Steps = 1252 State = success
# Steps = 1276 State = success
# Steps = 1189 State = success
# Steps = 1180 State = success
# Steps = 1170 State = success
# Steps = 1216 State = success
# Steps = 1191 State = success
# Steps = 1204 State = success
# Steps = 1432 State = success
# Steps = 1401 State = success
# Steps = 1553 State = success
# Steps = 1093 State = success
# Steps = 1486 State = success
# Steps = 1221 State = success
# Steps = 1103 State = success
# Steps = 1115 State = success
# Steps = 1304 State = success
# Steps = 1570 State = success
# Steps = 1162 State = success
# Steps = 1219 State = success
# Steps = 1238 State = success
# Steps = 1393 State = success
# Steps = 1296 State = success
# Steps = 1162 State = success
# Steps = 1219 State = success
# Steps = 1116 State = success
# Steps = 1397 State = success
# Steps = 1214 State = success
# Steps = 1390 State = success
# Steps = 1107 State = success
# Steps = 1208 State = success
# Steps = 1143 State = success
# Steps = 1361 State = success
# Steps = 1210 State = success
# Steps = 1197 State = success
# Steps = 1214 State = success
# Steps = 1379 State = success
# Steps = 1362 State = success
# Steps = 1237 State = success
# Steps = 1384 State = success
# Steps = 1201 State = success
# Steps = 1117 State = success
# Steps = 1122 State = success
# Steps = 1408 State = success
# Steps = 1526 State = success
# Steps = 1186 State = success
# Steps = 1611 State = success
# Steps = 1384 State = success
# Steps = 1126 State = success
# Steps = 1092 State = success
# Steps = 1299 State = success
# Steps = 1101 State = success
# Steps = 1137 State = success
# Steps = 1341 State = success
# Steps = 1273 State = success
# Steps = 1360 State = success
# Steps = 1196 State = success
# Steps = 1121 State = success
# Steps = 1443 State = success
# Steps = 1148 State = success
# Steps = 1417 State = success
# Steps = 1262 State = success
# Steps = 1275 State = success
# Steps = 1316 State = success
# Steps = 1112 State = success
# Steps = 1235 State = success
# Steps = 1486 State = success
# Steps = 1155 State = success
# Steps = 1118 State = success
# Steps = 1268 State = success
# Steps = 1212 State = success
# Steps = 1193 State = success
# Steps = 1062 State = success
# Steps = 1392 State = success
# Steps = 1621 State = success
# Steps = 1134 State = success
# Steps = 1327 State = success
# Steps = 1880 State = failed
# Steps = 1268 State = success
# Steps = 1232 State = success
# Steps = 1566 State = success
# Steps = 1275 State = success
# Steps = 1163 State = success
# Steps = 1401 State = failed
# Steps = 1301 State = success
# Steps = 1313 State = success
# Steps = 1356 State = success
# Steps = 1132 State = success
# Steps = 1436 State = success
# Steps = 1733 State = success
# Steps = 1273 State = success
# Steps = 1103 State = success
# Steps = 1262 State = success
# Steps = 1327 State = success
# Steps = 1154 State = success
# Steps = 1488 State = success
# Steps = 1295 State = success
# Steps = 1259 State = success
# Steps = 1199 State = success
# Steps = 1114 State = success
# Steps = 1232 State = success
# Steps = 1232 State = success
# Steps = 1320 State = success
# Steps = 1230 State = success
# Steps = 1290 State = success
# Steps = 1238 State = success
# Steps = 1097 State = success
# Steps = 1333 State = success
# Steps = 1312 State = success
# Steps = 1310 State = success
# Steps = 1187 State = success
# Steps = 1251 State = success
# Steps = 1178 State = success
# Steps = 1327 State = success
# Steps = 1119 State = success
# Steps = 1375 State = success
# Steps = 1188 State = success
# Steps = 1154 State = success
# Steps = 1343 State = success
# Steps = 1191 State = success
# Steps = 1269 State = success
# Steps = 1109 State = success
# Steps = 1298 State = success
# Steps = 1111 State = success
# Steps = 1476 State = success
# Steps = 1464 State = success
# Steps = 1329 State = success
# Steps = 1411 State = success
# Steps = 1554 State = success
# Steps = 1102 State = success
# Steps = 1269 State = success
# Steps = 1249 State = success
# Steps = 1118 State = success
# Steps = 1331 State = failed
# Steps = 1213 State = success
# Steps = 1184 State = success
# Steps = 1234 State = success
# Steps = 1251 State = success
# Steps = 1240 State = success
# Steps = 1372 State = success
# Steps = 1084 State = success
# Steps = 1472 State = success
# Steps = 1296 State = success
# Steps = 1238 State = success
# Steps = 1281 State = success
# Steps = 729 State = failed
# Steps = 1235 State = success
# Steps = 1238 State = success
# Steps = 1328 State = success
# Steps = 1356 State = success
# Steps = 1346 State = success
# Steps = 1332 State = success
# Steps = 1307 State = success
# Steps = 1225 State = success
# Steps = 1174 State = success
# Steps = 1262 State = success
# Steps = 1211 State = success
# Steps = 1473 State = success
# Steps = 1229 State = success
# Steps = 1190 State = success
# Steps = 1183 State = success
# Steps = 1142 State = success
# Steps = 1254 State = success
# Steps = 1104 State = success
# Steps = 1219 State = success
# Steps = 1472 State = success
# Steps = 1175 State = success
# Steps = 1235 State = success
# Steps = 1386 State = success
# Steps = 1144 State = success
# Steps = 1144 State = success
# Steps = 1283 State = success
# Steps = 1353 State = success
# Steps = 1223 State = success
# Steps = 1154 State = success
# Steps = 1300 State = success
# Steps = 1224 State = success
# Steps = 1714 State = success
# Steps = 1351 State = success
# Steps = 1346 State = success
# Steps = 1286 State = success
# Steps = 1413 State = success
# Steps = 1099 State = success
# Steps = 1319 State = success
# Steps = 1448 State = success
# Steps = 1336 State = success
# Steps = 1408 State = success
# Steps = 1378 State = success
# Steps = 1082 State = success
# Steps = 1180 State = success
# Steps = 1252 State = success
# Steps = 1354 State = success
# Steps = 1378 State = success
# Steps = 1168 State = success
# Steps = 1256 State = success
# Steps = 1083 State = success
# Steps = 1206 State = success
# Steps = 1217 State = success
# Steps = 1338 State = success
# Steps = 1164 State = success
# Steps = 1524 State = failed
# Steps = 1653 State = failed
# Steps = 1287 State = success
# Steps = 1297 State = success
# Steps = 1135 State = success
# Steps = 1251 State = success
# Steps = 1499 State = success
# Steps = 1124 State = success
# Steps = 1188 State = success
# Steps = 1334 State = success
# Steps = 1242 State = success
# Steps = 1143 State = success
# Steps = 1127 State = success
# Steps = 1385 State = success
# Steps = 1853 State = success
# Steps = 1577 State = success
# Steps = 1150 State = success
# Steps = 1430 State = success
# Steps = 1100 State = success
# Steps = 1134 State = success
# Steps = 1467 State = success
# Steps = 1236 State = success
# Steps = 1235 State = success
# Steps = 1191 State = success
# Steps = 1158 State = success
# Steps = 1273 State = success
# Steps = 1347 State = success
# Steps = 1220 State = success
# Steps = 1100 State = success
# Steps = 1203 State = success
# Steps = 1487 State = success
# Steps = 1404 State = success
# Steps = 1309 State = success
# Steps = 1379 State = success
# Steps = 1587 State = success
# Steps = 1364 State = success
# Steps = 1351 State = success
# Steps = 1210 State = success
# Steps = 1274 State = success
# Steps = 1213 State = success
# Steps = 1135 State = success
# Steps = 1346 State = success
# Steps = 1335 State = success
# Steps = 1294 State = success
# Steps = 1464 State = success
# Steps = 1130 State = success
# Steps = 1144 State = success
# Steps = 1142 State = success
# Steps = 1196 State = success
# Steps = 1164 State = success
# Steps = 1705 State = success
# Steps = 1437 State = success
# Steps = 1250 State = success
# Steps = 1284 State = success
# Steps = 1396 State = success
# Steps = 1212 State = success
# Steps = 1222 State = success
# Steps = 1200 State = success
# Steps = 1262 State = success
# Steps = 1374 State = success
# Steps = 1307 State = success
# Steps = 1414 State = success
# Steps = 763 State = failed
# Steps = 1279 State = success
# Steps = 1359 State = success
# Steps = 1115 State = success
# Steps = 1198 State = success
# Steps = 1144 State = success
# Steps = 1260 State = success
# Steps = 1264 State = success
# Steps = 1500 State = success
# Steps = 1211 State = success
# Steps = 1087 State = success
# Steps = 1240 State = success
# Steps = 1505 State = success
# Steps = 1137 State = success
# Steps = 1355 State = success
# Steps = 1100 State = success
# Steps = 1124 State = success
# Steps = 1117 State = success
# Steps = 1298 State = success
# Steps = 1228 State = success
# Steps = 1311 State = success
# Steps = 1276 State = success
# Steps = 1783 State = success
# Steps = 1318 State = success
# Steps = 1424 State = success
# Steps = 1135 State = success
# Steps = 1414 State = success
# Steps = 1218 State = success
# Steps = 1228 State = failed
# Steps = 1346 State = success
# Steps = 1467 State = success
# Steps = 1111 State = success
# Steps = 1162 State = success
# Steps = 1321 State = success
# Steps = 1463 State = success
# Steps = 1075 State = success
# Steps = 1328 State = success
# Steps = 1180 State = success
# Steps = 1270 State = success
# Steps = 1146 State = success
# Steps = 1305 State = success
# Steps = 1188 State = success
# Steps = 1604 State = success
# Steps = 1335 State = success
# Steps = 1517 State = success
# Steps = 1194 State = success
# Steps = 1335 State = success
# Steps = 1359 State = success
# Steps = 1168 State = success
# Steps = 1203 State = success
# Steps = 1345 State = success
# Steps = 1369 State = success
# Steps = 1114 State = success
# Steps = 1296 State = success
# Steps = 1085 State = success
# Steps = 1502 State = success
# Steps = 1131 State = success
# Steps = 1247 State = success
# Steps = 1229 State = success
# Steps = 1120 State = success
# Steps = 1361 State = success
# Steps = 1116 State = success
# Steps = 1157 State = failed
# Steps = 1156 State = success
# Steps = 1301 State = success
# Steps = 1096 State = success
# Steps = 1292 State = failed
# Steps = 1241 State = success
# Steps = 1206 State = success
# Steps = 1247 State = success
# Steps = 1307 State = success
# Steps = 1429 State = success
# Steps = 1316 State = success
# Steps = 1197 State = success
# Steps = 1269 State = success
# Steps = 1226 State = success
# Steps = 1439 State = success
# Steps = 1179 State = success
# Steps = 1190 State = success
# Steps = 1376 State = success
# Steps = 1285 State = success
# Steps = 1 State = failed
# Steps = 1124 State = success
# Steps = 1264 State = success
# Steps = 1165 State = success
# Steps = 1232 State = success
# Steps = 1345 State = success
# Steps = 1150 State = success
# Steps = 1182 State = success
# Steps = 1804 State = success
# Steps = 1180 State = success
# Steps = 1145 State = success
# Steps = 1448 State = success
# Steps = 1328 State = success
# Steps = 1309 State = success
# Steps = 1309 State = success
# Steps = 1211 State = success
# Steps = 1258 State = success
# Steps = 1196 State = success
# Steps = 1273 State = success
# Steps = 1337 State = success
# Steps = 1499 State = success
# Steps = 1335 State = success
# Steps = 1280 State = success
# Steps = 1236 State = success
# Steps = 4 State = failed
# Steps = 1295 State = success
# Steps = 1354 State = success
# Steps = 1156 State = failed
# Steps = 1555 State = success
# Steps = 1305 State = success
# Steps = 1366 State = success
# Steps = 1215 State = success
# Steps = 1400 State = success
# Steps = 1314 State = success
# Steps = 1395 State = success
# Steps = 1 State = failed
# Steps = 1307 State = success
# Steps = 1215 State = success
# Steps = 1257 State = success
# Steps = 1206 State = success
# Steps = 1464 State = success
# Steps = 1212 State = success
# Steps = 1224 State = success
# Steps = 1299 State = success
# Steps = 1171 State = success
# Steps = 1520 State = success
# Steps = 1297 State = success
# Steps = 1335 State = success
# Steps = 1103 State = success
# Steps = 1449 State = success
# Steps = 1332 State = success
# Steps = 1109 State = success
# Steps = 1181 State = success
# Steps = 1227 State = success
# Steps = 1643 State = success
# Steps = 1394 State = success
# Steps = 1126 State = success
# Steps = 1347 State = success
# Steps = 1476 State = failed
# Steps = 1345 State = success
# Steps = 1064 State = success
# Steps = 1264 State = success
# Steps = 1366 State = success
# Steps = 1133 State = success
# Steps = 1208 State = success
# Steps = 1546 State = success
# Steps = 1111 State = success
# Steps = 1180 State = success
# Steps = 1215 State = success
# Steps = 1429 State = success
# Steps = 1471 State = success
# Steps = 1339 State = success
# Steps = 1105 State = success
# Steps = 1202 State = success
# Steps = 1107 State = success
# Steps = 1336 State = success
# Steps = 1494 State = success
# Steps = 1324 State = success
# Steps = 1527 State = success
# Steps = 1237 State = success
# Steps = 1139 State = success
# Steps = 1274 State = success
# Steps = 1196 State = success
# Steps = 1189 State = success
# Steps = 1241 State = success
# Steps = 1275 State = success
# Steps = 1246 State = success
# Steps = 1219 State = success
# Steps = 1258 State = success
# Steps = 1166 State = success
# Steps = 1375 State = success
# Steps = 1369 State = success
# Steps = 1130 State = success
# Steps = 1365 State = success
# Steps = 1175 State = success
# Steps = 1266 State = success
# Steps = 1291 State = success
# Steps = 1249 State = success
# Steps = 1248 State = success
# Steps = 1120 State = success
# Steps = 1141 State = success
# Steps = 1179 State = success
# Steps = 1331 State = success
# Steps = 1303 State = success
# Steps = 1377 State = success
# Steps = 1297 State = success
# Steps = 1681 State = success
# Steps = 1279 State = success
# Steps = 1340 State = success
# Steps = 1245 State = success
# Steps = 1306 State = success
# Steps = 1138 State = success
# Steps = 1145 State = success
# Steps = 1223 State = success
# Steps = 1111 State = success
# Steps = 1510 State = success
# Steps = 1288 State = success
# Steps = 1170 State = success
# Steps = 1373 State = success
# Steps = 1283 State = success
# Steps = 1461 State = failed
# Steps = 1196 State = success
# Steps = 1212 State = success
# Steps = 1081 State = success
# Steps = 1226 State = success
# Steps = 1206 State = success
# Steps = 1239 State = success
# Steps = 1377 State = success
# Steps = 1150 State = success
# Steps = 1258 State = success
# Steps = 1160 State = success
# Steps = 1168 State = success
# Steps = 1538 State = success
# Steps = 1225 State = success
# Steps = 1305 State = success
# Steps = 1545 State = success
# Steps = 1177 State = success
# Steps = 1305 State = success
# Steps = 1313 State = success
# Steps = 1554 State = success
# Steps = 1245 State = success
# Steps = 1351 State = success
# Steps = 1495 State = success
# Steps = 1440 State = success
# Steps = 1445 State = success
# Steps = 1491 State = success
# Steps = 1218 State = success
# Steps = 1179 State = success
# Steps = 1291 State = success
# Steps = 1478 State = success
# Steps = 1118 State = success
# Steps = 1216 State = success
# Steps = 1307 State = success
# Steps = 1204 State = success
# Steps = 1595 State = success
# Steps = 1244 State = success
# Steps = 1149 State = success
# Steps = 1233 State = success
# Steps = 1262 State = success
# Steps = 1140 State = success
# Steps = 1174 State = success
# Steps = 1327 State = success
# Steps = 1166 State = success
# Steps = 1303 State = success
# Steps = 1112 State = success
# Steps = 1301 State = success
# Steps = 1440 State = success
# Steps = 1278 State = success
# Steps = 1470 State = success
# Steps = 1117 State = success
# Steps = 1329 State = success
# Steps = 1205 State = success
# Steps = 1189 State = success
# Steps = 1470 State = success
# Steps = 1253 State = success
# Steps = 1484 State = success
# Steps = 1283 State = success
# Steps = 1212 State = success
# Steps = 1297 State = success
# Steps = 1172 State = success
# Steps = 1284 State = success
# Steps = 1343 State = success
# Steps = 1181 State = success
# Steps = 1252 State = success
# Steps = 1147 State = success
# Steps = 1817 State = success
# Steps = 1072 State = success
# Steps = 1163 State = success
# Steps = 1428 State = success
# Steps = 1237 State = success
# Steps = 1370 State = success
# Steps = 1131 State = success
# Steps = 1159 State = success
# Steps = 1277 State = success
# Steps = 1256 State = success
# Steps = 1502 State = success
# Steps = 1381 State = success
# Steps = 1406 State = success
# Steps = 1253 State = success
# Steps = 1435 State = success
# Steps = 1293 State = success
# Steps = 1238 State = success
# Steps = 1372 State = success
# Steps = 1151 State = success
# Steps = 1175 State = success
# Steps = 1170 State = success
# Steps = 1275 State = success
# Steps = 1315 State = success
# Steps = 1192 State = success
# Steps = 1139 State = success
# Steps = 1508 State = success
# Steps = 1599 State = success
# Steps = 1328 State = success
# Steps = 1359 State = success
# Steps = 1425 State = success
# Steps = 1090 State = success
# Steps = 1201 State = success
# Steps = 1621 State = success
# Steps = 1411 State = success
# Steps = 1303 State = success
# Steps = 1415 State = success
# Steps = 1353 State = success
# Steps = 1276 State = success
# Steps = 1276 State = success
# Steps = 1293 State = success
# Steps = 1456 State = success
# Steps = 1661 State = success
# Steps = 1080 State = success
# Steps = 1122 State = success
# Steps = 1313 State = success
# Steps = 1332 State = success
# Steps = 1543 State = success
# Steps = 1250 State = success
# Steps = 1174 State = success
# Steps = 1421 State = success
# Steps = 1239 State = success
# Steps = 1300 State = success
# Steps = 944 State = failed
# Steps = 1461 State = success
# Steps = 1220 State = success
# Steps = 1180 State = success
# Steps = 1100 State = success
# Steps = 1105 State = success
# Steps = 1370 State = success
# Steps = 1389 State = success
# Steps = 1332 State = success
# Steps = 1102 State = success
# Steps = 1351 State = success
# Steps = 1423 State = success
# Steps = 1185 State = success
# Steps = 1575 State = success
# Steps = 1189 State = success
# Steps = 1129 State = success
# Steps = 1221 State = success
# Steps = 1602 State = success
# Steps = 1521 State = success
# Steps = 1299 State = success
# Steps = 1267 State = success
# Steps = 1319 State = success
# Steps = 1143 State = success
# Steps = 1101 State = success
# Steps = 1215 State = success
# Steps = 1159 State = success
# Steps = 1062 State = success
# Steps = 1309 State = success
# Steps = 1338 State = success
# Steps = 1228 State = success
# Steps = 1328 State = success
# Steps = 1303 State = success
# Steps = 1474 State = success
# Steps = 1241 State = success
# Steps = 1312 State = success
# Steps = 1376 State = success
# Steps = 1095 State = success
# Steps = 1364 State = success
# Steps = 1384 State = success
# Steps = 1374 State = success
# Steps = 1188 State = success
# Steps = 1319 State = success
# Steps = 1190 State = success
# Steps = 1279 State = success
# Steps = 1269 State = success
# Steps = 1133 State = success
# Steps = 1210 State = success
# Steps = 1248 State = success
# Steps = 1323 State = success
# Steps = 1209 State = success
# Steps = 1183 State = success
# Steps = 1392 State = success
# Steps = 1178 State = success
# Steps = 1142 State = success
# Steps = 1322 State = failed
# Steps = 1426 State = success
# Steps = 1383 State = success
# Steps = 1240 State = success
# Steps = 1276 State = success
# Steps = 1315 State = success
# Steps = 1326 State = success
# Steps = 1294 State = success
# Steps = 1211 State = success
# Steps = 1246 State = success
# Steps = 1574 State = success
# Steps = 1515 State = success
# Steps = 1341 State = success
# Steps = 1176 State = success
# Steps = 1183 State = success
# Steps = 1349 State = success
# Steps = 1181 State = success
# Steps = 1446 State = success
# Steps = 1361 State = success
# Steps = 1252 State = success
# Steps = 1453 State = success
# Steps = 1343 State = success
# Steps = 1414 State = success
# Steps = 1199 State = success
# Steps = 1452 State = success
# Steps = 1316 State = success
# Steps = 1378 State = success
# Steps = 1336 State = success
# Steps = 1271 State = success
# Steps = 1244 State = success
# Steps = 1135 State = success
# Steps = 1371 State = success
# Steps = 1134 State = success
# Steps = 1215 State = success
# Steps = 1498 State = success
# Steps = 1250 State = success
# Steps = 1202 State = success
# Steps = 1275 State = success
# Steps = 1217 State = success
# Steps = 1329 State = success
# Steps = 1158 State = success
# Steps = 1121 State = success
# Steps = 1394 State = success
# Steps = 1180 State = success
# Steps = 1266 State = success
# Steps = 1283 State = success
# Steps = 1137 State = success
# Steps = 1275 State = success
# Steps = 1244 State = success
# Steps = 1257 State = success
# Steps = 1548 State = success
# Steps = 1142 State = success
# Steps = 1197 State = success
# Steps = 1241 State = success
# Steps = 1341 State = success
# Steps = 1295 State = success
# Steps = 1295 State = success
# Steps = 1126 State = success
# Steps = 1507 State = success
# Steps = 1248 State = success
# Steps = 1163 State = success
# Steps = 1238 State = success
# Steps = 1082 State = success
# Steps = 1307 State = success
# Steps = 1432 State = success
# Steps = 1181 State = success
# Steps = 1387 State = success
# Steps = 1056 State = success
# Steps = 1103 State = success
# Steps = 1077 State = success
# Steps = 1258 State = success
# Steps = 1363 State = success
# Steps = 1421 State = success
# Steps = 1192 State = success
# Steps = 1422 State = success
# Steps = 1229 State = success
# Steps = 1289 State = success
# Steps = 1531 State = success
# Steps = 1244 State = success
# Steps = 1110 State = success
# Steps = 1183 State = success
# Steps = 1137 State = success
# Steps = 1280 State = success
# Steps = 1280 State = success
# Steps = 1268 State = success
# Steps = 1222 State = success
# Steps = 1374 State = success
# Steps = 1190 State = success
# Steps = 1156 State = success
# Steps = 1142 State = success
# Steps = 1343 State = success
# Steps = 1171 State = success
# Steps = 1343 State = success
# Steps = 1756 State = success
# Steps = 1413 State = success
# Steps = 1298 State = success
# Steps = 1253 State = success
# Steps = 1284 State = success
# Steps = 1233 State = success
# Steps = 1184 State = success
# Steps = 1107 State = success
# Steps = 1225 State = success
# Steps = 1269 State = success
# Steps = 1288 State = success
# Steps = 1220 State = success
# Steps = 1166 State = success
# Steps = 1287 State = success
# Steps = 1127 State = success
# Steps = 1163 State = success
# Steps = 1376 State = success
# Steps = 1310 State = success
# Steps = 1400 State = success
# Steps = 1140 State = success
# Steps = 1188 State = success
# Steps = 1141 State = success
# Steps = 1173 State = success
# Steps = 1428 State = success
# Steps = 1234 State = success
# Steps = 1320 State = success
# Steps = 1491 State = success
# Steps = 1301 State = success
# Steps = 1313 State = success
# Steps = 1233 State = success
# Steps = 1154 State = success
# Steps = 1802 State = success
# Steps = 1434 State = success
# Steps = 1235 State = success
# Steps = 1096 State = success
# Steps = 1234 State = success
# Steps = 1163 State = success
# Steps = 1597 State = success
# Steps = 1519 State = success
# Steps = 1283 State = success
# Steps = 1310 State = success
# Steps = 1374 State = success
# Steps = 1481 State = success
# Steps = 1149 State = success
# Steps = 1298 State = success
# Steps = 1551 State = success
# Steps = 1622 State = success
# Steps = 1101 State = success
# Steps = 1166 State = success
# Steps = 1347 State = success
# Steps = 1170 State = success
# Steps = 1758 State = success
# Steps = 1346 State = success
# Steps = 1305 State = success
# Steps = 1215 State = success
# Steps = 1399 State = success
# Steps = 1322 State = success
# Steps = 1182 State = success
# Steps = 1244 State = success
# Steps = 1188 State = success
# Steps = 1150 State = success
# Steps = 1323 State = success
# Steps = 1276 State = success
# Steps = 1230 State = success
# Steps = 1245 State = success
# Steps = 1130 State = success
# Steps = 1205 State = success
# Steps = 1565 State = success
# Steps = 1211 State = success
# Steps = 1200 State = success
# Steps = 1181 State = success
# Steps = 1135 State = success
# Steps = 1271 State = success
# Steps = 1207 State = success
# Steps = 1368 State = success
# Steps = 1495 State = success
# Steps = 1281 State = success
# Steps = 1290 State = success
# Steps = 1461 State = success
# Steps = 1173 State = success
# Steps = 1185 State = success
# Steps = 1333 State = success
# Steps = 1091 State = success
# Steps = 1461 State = success
# Steps = 1492 State = success
# Steps = 1313 State = success
# Steps = 1090 State = success
# Steps = 1646 State = success
# Steps = 1139 State = success
# Steps = 1168 State = success
# Steps = 1204 State = success
# Steps = 1293 State = success
# Steps = 1307 State = success
# Steps = 1404 State = success
# Steps = 1386 State = success
# Steps = 1186 State = success
# Steps = 1395 State = success
# Steps = 1388 State = success
# Steps = 1484 State = success
# Steps = 1348 State = success
# Steps = 1217 State = success
# Steps = 1329 State = success
# Steps = 1252 State = success
# Steps = 1129 State = success
# Steps = 1208 State = success
# Steps = 1342 State = success
# Steps = 1220 State = success
# Steps = 1524 State = success
# Steps = 1135 State = success
# Steps = 1163 State = success
# Steps = 1183 State = success
# Steps = 1478 State = success
# Steps = 1653 State = success
# Steps = 1318 State = success
# Steps = 1253 State = success
# Steps = 1406 State = success
# Steps = 1120 State = success
# Steps = 1312 State = success
# Steps = 1298 State = success
# Steps = 1219 State = success
# Steps = 1342 State = success
# Steps = 1297 State = success
# Steps = 1242 State = success
# Steps = 1143 State = success
# Steps = 1362 State = success
# Steps = 1439 State = success
# Steps = 1276 State = success
# Steps = 1189 State = success
# Steps = 1482 State = success
# Steps = 1075 State = success
# Steps = 1378 State = success
# Steps = 1387 State = success
# Steps = 1334 State = success
# Steps = 1444 State = success
# Steps = 1272 State = success
# Steps = 1206 State = success
# Steps = 1449 State = success
# Steps = 1145 State = success
# Steps = 1331 State = success
# Steps = 1136 State = success
# Steps = 1350 State = success
# Steps = 1196 State = success
# Steps = 1205 State = success
# Steps = 1285 State = success
# Steps = 1304 State = success
# Steps = 1222 State = success
# Steps = 1402 State = success
# Steps = 1196 State = success
# Steps = 1303 State = success
# Steps = 1354 State = success
# Steps = 1211 State = success
# Steps = 1112 State = success
# Steps = 1363 State = success
# Steps = 1358 State = success
# Steps = 1202 State = success
# Steps = 1263 State = success
# Steps = 1175 State = success
# Steps = 1278 State = success
# Steps = 1242 State = success
# Steps = 1165 State = success
# Steps = 1183 State = success
# Steps = 1306 State = success
# Steps = 1345 State = success
# Steps = 1280 State = success
# Steps = 1400 State = success
# Steps = 1455 State = success
# Steps = 1187 State = success
# Steps = 1158 State = success
# Steps = 1246 State = success
# Steps = 1277 State = success
# Steps = 1164 State = success
# Steps = 1340 State = success
# Steps = 1376 State = success
# Steps = 1201 State = success
# Steps = 1223 State = success
# Steps = 1411 State = success
# Steps = 1174 State = success
# Steps = 1181 State = success
# Steps = 1347 State = success
# Steps = 1310 State = success
# Steps = 1149 State = success

# %% [markdown]
# <a name="Inference"></a>
# # Inference
# Now let's try the model we just trained!

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 1024,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-10-06
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new short 2048 strategy using only native Python code.
# You are given a list of list of numbers for the current board state.
# Output one action for "W", "A", "S", "D" on what is the optimal next step.
# Output your new short function in backticks using the format below:
# ```python
# def strategy(board):
#     return "W" # Example
# ```
# All helper functions should be inside def strategy. Only output the short function `strategy`.<|end|><|start|>assistant<|channel|>analysis<|message|>We need a short strategy that picks best move using basic heuristics. Use simple scoring: prefer moving to increase score: choose move that gives largest tile sum after simulation. Write quick function.<|end|><|start|>assistant<|channel|>final<|message|>```python
# def strategy(board):
#     import itertools
#     dirs = ["W","A","S","D"]
#     best_dir = None
#     best_val = -1
#     for d in dirs:
#         new_board = [row[:] for row in board]
#         moved = False
#         if d == "W":
#             for col in range(4):
#                 temp = [new_board[r][col] for r in range(4) if new_board[r][col]]
#                 merged = []
#                 i=0
#                 while i<len(temp):
#                     if i+1<len(temp) and temp[i]==temp[i+1]:
#                         merged.append(temp[i]*2); i+=2
#                     else:
#                         merged.append(temp[i]); i+=1
#                 for r in range(4):
#                     new_board[r][col]=merged[r] if r<len(merged) else 0
#         elif d == "S":
#             for col in range(4):
#                 temp = [new_board[r][col] for r in range(4) if new_board[r][col]]
#                 merged = []
#                 i=len(temp)-1
#                 while i>=0:
#                     if i-1>=0 and temp[i]==temp[i-1]:
#                         merged.insert(0,temp[i]*2); i-=2
#                     else:
#                         merged.insert(0,temp[i]); i-=1
#                 for r in range(4):
#                     new_board[r][col]=merged[r] if r<len(merged) else 0
#         elif d == "A":
#             for r in range(4):
#                 temp = [new_board[r][c] for c in range(4) if new_board[r][c]]
#                 merged = []
#                 i=0
#                 while i<len(temp):
#                     if i+1<len(temp) and temp[i]==temp[i+1]:
#                         merged.append(temp[i]*2); i+=2
#                     else:
#                         merged.append(temp[i]); i+=1
#                 for c in range(4):
#                     new_board[r][c]=merged[c] if c<len(merged) else 0
#         elif d == "D":
#             for r in range(4):
#                 temp = [new_board[r][c] for c in range(4) if new_board[r][c]]
#                 merged = []
#                 i=len(temp)-1
#                 while i>=0:
#                     if i-1>=0 and temp[i]==temp[i-1]:
#                         merged.insert(0,temp[i]*2); i-=2
#                     else:
#                         merged.insert(0,temp[i]); i-=1
#                 for c in range(4):
#                     new_board[r][c]=merged[c] if c<len(merged) else 0
#         val = sum(map(sum,new_board))
#         if val>best_val:
#             best_val, best_dir = val, d
#     return best_dir
# ```<|return|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 or `MXFP4`
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `mxfp4` for MXFP4 (OpenAI's GPT-OSS native precision). We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge and push to hub in mxfp4 4bit format
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "mxfp4")
if False:
    model.push_to_hub_merged("repo_id/repo_name", tokenizer, token = "hf...", save_method = "mxfp4")

# Merge and push to hub in 16bit
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "merged_16bit")
if False: # Pushing to HF Hub
    model.push_to_hub_merged("hf/gpt-oss-finetune", tokenizer, save_method = "merged_16bit", token = "")

# %% [markdown]
# # And we're done!
# Congratulations you just learned how to do reinforcement learning with GPT-OSS! There were some advanced topics explained in this notebook - to learn more about GPT-OSS and RL, there are more docs in Unsloth's [Reinforcement Learning Guide with GPT-OSS](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning)
#
# This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
